# %%
import sys, os
import netCDF4 as nc
from scipy.interpolate import griddata
import numpy as np
import pandas as pd 
from time import process_time
#from memory_profiler import profile
import datetime

# Get current date
current_date = datetime.datetime.now()

# Format date as yymmdd
date_string = current_date.strftime('%y%m%d')

def main():
    '''
    args = sys.argv[1:]

    if  len(sys.argv) != 3 or sys.argv[1] == '--help':  # sys.argv includes the script name as the first argument
        print("Example use: python NA_surfdataGEN.py <input_path> <domain_name> <mask_file> <output_domain_type>")
        print("<input_path: path to the input surfdata>")
        print("<domain_name: unique name for the project or domain>")
        print("<mask_file: one forcing data>")        
        print(" The code generate TESSFA surfdata from 0.5x0.5 degree globla surfdata")
        print(" The code requires a 0.5x0.5 degree globla surfdata (surfdata.nc)")
        print(" The code requires a domain mask information (surfdata.nc)")        
        exit(0)

    input_path = args[0]
    if not input_path.endswith("/"): input_path=input_path+'/'
    domain_name = args[1]

    full_domain = input_path + domain_name
    mask_file = args[2]

    domain_type = args[3]
    '''

    # Get current date
    current_date = datetime.datetime.now()

    # Format date as yymmdd
    date_string = current_date.strftime('%y%m%d')

    domain_type = '1'

    if domain_type =='1':   domain_name = 'domain.lnd.TES_PT.4km.1d.c240827.nc'     
    if domain_type =='2':   domain_name = 'domain.lnd.TES_PT.4km.2d.c240827.nc'  
        
    mask_file = 'TES_BOT_domain1.nc'     
    output_file = domain_name.replace('domain.lnd', 'surfdata')

    print("the domain file is " + domain_name)
    print("the output file is " + output_file)
        
    # Only variables listed will be processed

    # nearest neighbor:"double" variables
    Variable_nearest = ['SLOPE', 'TOPO', 'PCT_GLACIER', 'PCT_LAKE', 'STD_ELEV']
    # nearest neighbor:"int" variables
    Variable_nearest += ['PFTDATA_MASK','SOIL_COLOR', 'SOIL_ORDER', 'abm']
    # nearest neighbor:"double" variables (added 11/07/22023)
    Variable_nearest += ['EF1_BTR', 'EF1_CRP', 'EF1_FDT', 'EF1_FET', 'EF1_GRS', 'EF1_SHR']
    # nearest neighbor: "double" variables (added 11/10/2023)
    Variable_nearest += ['PCT_SAND', 'PCT_CLAY','ORGANIC' ,'PCT_NAT_PFT', 
            'MONTHLY_LAI', 'MONTHLY_SAI' ,'MONTHLY_HEIGHT_TOP', 'MONTHLY_HEIGHT_BOT']

    # nearest neighbor:"int" variables (gridcell)
    Variable_urban_nearest = ['URBAN_REGION_ID']
    # nearest neighbor:"int" variables (numurbl, gridcell)
    Variable_urban_nearest += ['NLEV_IMPROAD' ]
    # nearest neighbor:"double" variables (numurbl, gridcell)
    Variable_urban_nearest += ['T_BUILDING_MAX', 'T_BUILDING_MIN',
            'WIND_HGT_CANYON','WTLUNIT_ROOF','WTROAD_PERV','THICK_ROOF',
            'THICK_WALL','PCT_URBAN','HT_ROOF','EM_IMPROAD','EM_PERROAD',
            'EM_ROOF','EM_WALL','CANYON_HWR']
    # nearest neighbor:"double" variables (nlevurb, numurbl, gridcell)
    Variable_urban_nearest += ['TK_IMPROAD','TK_ROOF','TK_WALL', 
                                     'CV_IMPROAD', 'CV_ROOF', 'CV_WALL']

    # nearest neighbor:"double" variables (numrad, numurbl, gridcell)
    Variable_urban_nearest += ['ALB_IMPROAD_DIF','ALB_IMPROAD_DIR','ALB_PERROAD_DIF',
            'ALB_PERROAD_DIR','ALB_ROOF_DIF', 'ALB_ROOF_DIR',
            'ALB_WALL_DIF', 'ALB_WALL_DIR']

    Variable_nearest += Variable_urban_nearest

    # linear interpolation of "double" variables
    Variable_linear = ['FMAX', 'Ws', 'ZWT0', 'binfl', 'gdp', 
                    'peatf', 'Ds', 'Dsmax', 'F0', 'LAKEDEPTH',
                   'LANDFRAC_PFT','P3', 'PCT_NATVEG', 'PCT_WETLAND', 
                    'SECONDARY_P', 'OCCLUDED_P', 'LABILE_P']

    # linear: "double" variables (added 11/07/22023)
    Variable_linear += ['APATITE_P', 'PCT_CROP']


    # Open the source file
    src = nc.Dataset('surfdata.nc', 'r')
    # points = [y,x] coordinates for src's grid
    src_resx = 0.5
    src_resy = 0.5
    src_lat = src.variables['LATIXY'][...]  
    src_lon = src.variables['LONGXY'][...]
    #src_x,src_y = Tlonlat2xy.transform(src_lon,src_lat)
    src_lon[src_lon<0.0]=360+src_lon[src_lon<0.0]
    
    # Create a new file      
    if os.path.isfile(output_file):
        # If it does, delete it
        os.remove(output_file)
        
    dst = nc.Dataset(output_file, 'w')

    # Copy dimensions
    for name, dimension in src.dimensions.items():
        dst.createDimension(
            name, (len(dimension) if not dimension.isunlimited() else None))

    # Copy global attributes
    dst.setncatts(src.__dict__)

    # get the fine resolution data and the locations (lat, lon) from the forcing dataset

    # get the fine resolution data and the locations (lat, lon)
    #r_daymet = nc.Dataset('clmforc.Daymet4.1km.TBOT.2014-01.nc', 'r', format='NETCDF4')
    r_mask = nc.Dataset(mask_file, 'r', format='NETCDF4')    
    x_dim = r_mask['lon'][...]  # 1D x-axis
    y_dim = r_mask['lat'][...]  # 1D y-axis
    TBOT = r_mask.variables['TBOT'][0,:,:]

    grid_ids = np.linspace(0, len(x_dim)*len(y_dim)-1, len(x_dim)*len(y_dim), dtype=int)
    grid_ids = grid_ids.reshape(TBOT.shape)
    grid_xids = np.indices(grid_ids.shape)[1]
    grid_yids = np.indices(grid_ids.shape)[0]

    # setup the bool_mask and mesh of the TESSFA domain (lon, lat)
    bool_mask = ~np.isnan(TBOT)
    grid_x, grid_y = np.meshgrid(x_dim,y_dim)

    grid_lat = np.copy(grid_y[bool_mask])
    grid_lon = np.copy(grid_x[bool_mask])
    grid_lon[grid_lon<0.0]=360+grid_lon[grid_lon<0.0]
    
    gridcells= len(grid_lon)

    print(TBOT.shape,bool_mask.shape, grid_x.shape, grid_lon.shape, gridcells)
    #del grid_x, grid_y

    # make sure the xc, yc, and area are identical in both domain and surfdata 
    
    r_tessfa = nc.Dataset(domain_name, 'r', format='NETCDF4')
    LONGXY = r_tessfa.variables['xc'][...]  # longitude of gridcell center
    LATIXY = r_tessfa.variables['yc'][...]  # latitude of gridcell center
    AREA = r_tessfa.variables['area'][...]

    '''if domain_type == "2": 
        grid_xc = r_tessfa.variables['xc'][...]  # longitude of gridcell center
        grid_lon[grid_lon < 0.0] = 360 + grid_lon[grid_lon < 0.0]
    
        grid_lat = r_tessfa.variables['yc'][...]  # latitude of gridcell center
        
        gridID = r_tessfa.variables['gridID'][...]  

        print("shape of gridID", gridID.shape, r_tessfa.variables['gridID'].shape)
        
        AREA = r_tessfa.variables['area'][...]  # Area is in (lat, lon)
        y_dim = AREA.shape[0]  # 1D x-axis
        x_dim = AREA.shape[1]  # 1D y-axis

        print(" size and shape of grid_lat",  grid_lat.size, grid_lat.shape)'''
    
    # prepare the data source with points_in_daymet_land  (witn lon, lat)
    idxy = np.nonzero((src_lat<=np.amax(grid_lat)+src_resy) & (src_lat>=np.amin(grid_lat)-src_resy) & \
                      (src_lon<=np.amax(grid_lon)+src_resx) & (src_lon>=np.amin(grid_lon)-src_resx) )

    
    points_in_tessfa_land = {}
    points_in_tessfa_land[0] = src_lat[idxy]
    points_in_tessfa_land[1] = src_lon[idxy]
    points_in_tessfa_land[2] = idxy[0]
    points_in_tessfa_land[3] = idxy[1]
    land_points = len(points_in_tessfa_land[0])
    points=np.zeros((land_points, 2), dtype='double')
    points[:,0] = src_lat[idxy]
    points[:,1] = src_lon[idxy]

    # Create new dimensions for TES domain
    dst.createDimension('lon', x_dim.size)
    dst.createDimension('lat', y_dim.size)

    dst_var = dst.createVariable('lon', np.float64, ('lon'), zlib=True, complevel=5)
    dst_var.units = "degree"
    dst_var.long_name = "longitude coordinate"
    dst_var.standard_name = "x_project_coordinate"
    dst['lon'][...] = np.copy(x_dim)
    dst_var = dst.createVariable('lat', np.float64, ('lat'), zlib=True, complevel=5)
    dst_var.units = "degree"
    dst_var.long_name = "latitude coordinate"
    dst_var.standard_name = "projection_y_coordinate"
    dst['lat'][...] = np.copy(y_dim)
    
#########  the default format should be 2D 
    
    if (domain_type == '1'):
    
        dst_var = dst.createVariable('lon2D', np.float64, ('lat','lon'), zlib=True, complevel=5)
        dst_var.units = "degrees_east"
        dst_var.long_name = "longitude coordinate"
        dst_var.standard_name = "longitude"
        dst['lon2D'][...] = np.copy(grid_x)
        dst_var = dst.createVariable('lat2D', np.float64, ('lat','lon'), zlib=True, complevel=5)
        dst_var.units = "degrees_north"
        dst_var.long_name = "latitude coordinate"
        dst_var.standard_name = "latitude"
        dst['lat2D'][...] = np.copy(grid_y)

        dst.createDimension('gridcell', gridcells)
        
        dst_var = dst.createVariable('gridID', np.int32, ('gridcell'), zlib=True, complevel=5)
        dst_var.long_name = 'gridId in the TES domain'
        dst_var.decription = "start from #0 at the upper left corner of the domain, covering all land and ocean gridcells" 
        dst['gridID'][...] = np.copy(grid_ids[bool_mask]) 
        
        dst_var = dst.createVariable('gridXID', np.int32, ('gridcell'), zlib=True, complevel=5)
        dst_var.long_name = 'gridId x in the TESSFA domain'
        dst_var.decription = "start from #0 at the upper left corner and from west to east of the domain, with gridID=gridXID+gridYID*x_dim" 
        dst.variables['gridXID'][...] = np.copy(grid_xids[bool_mask])
    
        dst_var = dst.createVariable('gridYID', np.int32, ('gridcell'), zlib=True, complevel=5)
        dst_var.long_name = 'gridId y in the TESSFA domain'
        dst_var.decription = "start from #0 at the upper left corner and from north to south of the domain, with gridID=gridXID+gridYID*y_dim" 
        dst.variables['gridYID'][...] = np.copy(grid_yids[bool_mask])

    else:
        dst_var = dst.createVariable('gridID', np.int32, ('lat','lon'), zlib=True, complevel=5)
        dst_var.long_name = 'gridId in the TESSFA domain'
        dst_var.decription = "start from #0 at the upper left corner of the domain, covering all land and ocean gridcells"
        dst.variables['gridID'][...] = np.copy(grid_ids)

        dst_var = dst.createVariable('gridXID', np.int32, ('lat','lon'), zlib=True, complevel=5)
        dst_var.long_name = 'gridId x in the TESSFA domain'
        dst_var.decription = "start from #0 at the upper left corner and from west to east of the domain, with gridID=gridXID+gridYID*x_dim"
        dst.variables['gridXID'][...] = np.copy(grid_xids)

        dst_var = dst.createVariable('gridYID', np.int32, ('lat','lon'), zlib=True, complevel=5)
        dst_var.long_name = 'gridId y in the TESSFA domain'
        dst_var.decription = "start from #0 at the upper left corner and from north to south of the domain, with gridID=gridXID+gridYID*y_dim"
        dst.variables['gridYID'][...] = np.copy(grid_yids)


    count = 0 # record how may 2D layers have been processed 

    # Copy variables
    for name, variable in src.variables.items():
        start = process_time()
        print("Checking on varibale: "+ name + " dimensions: " + str(variable.dimensions))
        
        # Check if the last two dimensions are lsmlat and lsmlon
        if (variable.dimensions[-2:] == ('lsmlat', 'lsmlon')):
            # Determine the interpolation method
            if name in Variable_linear:
                iMethod = 'linear'
            else:
                iMethod = 'nearest'

            print("Working on varibale: "+ name + " dimensions: " + str(variable.dimensions))

            # create variables with the new dimensions

            if variable.datatype == np.int32:
                fill_value = -9999  # or any other value that you want to use to represent missing data
            else:
                fill_value = np.nan

            x = dst.createVariable(name, variable.datatype, variable.dimensions[:-2]+ ('gridcell',), fill_value = fill_value, zlib=True, complevel=5)
                
	    # Copy variable attributes
            dst[name].setncatts(src[name].__dict__)

            # prepare the array for the interpolated result
            f_data1 = np.zeros(gridcells, dtype=variable.datatype)

            # original variable data (source) that need to be interpolated
            o_data=np.zeros(land_points, dtype=variable.datatype)
             
            # Handle variables with two dimensions
            if (len(variable.dimensions) == 2):
                source = src[name][:]
                o_data = source[points_in_tessfa_land[2][:],points_in_tessfa_land[3][:]]
                f_data1 = griddata(points, o_data, (grid_lat, grid_lon), method=iMethod)
                if name=='AREA': f_data1[...] = AREA  # need to get the AREA value from Domain files
                if name=='LONGXY': f_data1[...] = LONGXY
                if name=='LATIXY': f_data1[...] = LATIXY
                
                if (domain_type == '1'):
                    # Assign the interpolated data
                    dst[name][...] = np.copy(f_data1)
                    
                else:
      
                # put the masked data back to the data (with the NA land mask

                    f_data = np.ma.array(np.empty((len(y_dim),len(x_dim)), dtype=variable.datatype), mask=bool_mask, fill_value=fill_value)
                    f_data =  np.where(f_data.mask, f_data, fill_value)
                    f_data[bool_mask]=f_data1 
                    
                # Assign the interpolated data
                    dst[name][...] = np.copy(f_data)
                    
                '''print("o_data, f_data1, f_data, dst: max/min/sum")  
                print(np.nanmax(o_data), np.nanmax(f_data1),np.nanmax(f_data[f_data != -9999]),np.nanmax(dst[name]))
                print(np.nanmin(o_data), np.nanmin(f_data1),np.nanmin(f_data[f_data != -9999]),np.nanmin(dst[name]))   
                print(np.nansum(o_data), np.nansum(f_data1),np.nansum(f_data[f_data != -9999]),np.nansum(dst[name]))'''  

                count = count + 1

            # Handle variables with three dimensions
            if (len(variable.dimensions) == 3):
                for index in range(variable.shape[0]):
                    # get all the source data (global)
                    source = src[name][index,:,:]
                    o_data = source[points_in_tessfa_land[2][:],points_in_tessfa_land[3][:]]
                    f_data1 = griddata(points, o_data, (grid_lat, grid_lon), method=iMethod)
                    
                    if (domain_type =='1'):
                        # Assign the interpolated data
                        dst[name][index,...] = np.copy(f_data1)
                    else:

                    # create a mask array to hold the interpolated data

                        f_data = np.ma.array(np.empty((len(y_dim),len(x_dim)), dtype=variable.datatype), mask=bool_mask, fill_value=fill_value)
                        f_data =  np.where(f_data.mask, f_data, fill_value)
                        f_data[bool_mask]=f_data1 
    
                    # Assign the interpolated data to dst.variable
                        dst[name][index,...] = np.copy(f_data)
                        
                    '''print("o_data, f_data1, f_data, dst: max/min/sum")  
                    print(np.nanmax(o_data), np.nanmax(f_data1),np.nanmax(f_data[f_data != -9999]),np.nanmax(dst[name][index,:,:]))
                    print(np.nanmin(o_data), np.nanmin(f_data1),np.nanmin(f_data[f_data != -9999]),np.nanmin(dst[name][index,:,:]))   
                    print(np.nansum(o_data), np.nansum(f_data1),np.nansum(f_data[f_data != -9999]),np.nansum(dst[name][index,:,:]))'''  

                count = count + variable.shape[0]

            # Handle variables with four dimensions
            if (len(variable.dimensions) == 4):
                for index1 in range(variable.shape[0]):
                    for index2 in range(variable.shape[1]):
                        # get all the source data (global)

                        source = src[name][index1, index2,:, :]
                        o_data = source[points_in_tessfa_land[2][:],points_in_tessfa_land[3][:]]
                        
                        f_data1 = griddata(points, o_data, (grid_lat, grid_lon), method=iMethod)                      
                        if (domain_type == '1'):
                            # Assign the interpolated data
                            dst[name][index1,index2,...] = np.copy(f_data1)
                        else:

                        # create a mask array to hold the interpolated data
                            f_data = np.ma.array(np.empty((len(y_dim),len(x_dim)), dtype=variable.datatype), mask=bool_mask, fill_value=fill_value)
                            f_data =  np.where(f_data.mask, f_data, fill_value)
                            f_data[bool_mask]=f_data1 
    
                        # Assign the interpolated data to dst.variable
                            dst[name][index1,index2,...] = np.copy(f_data)

                        #print("o_data, f_data1, f_data, dst: max/min/sum")  
                        #print(np.nanmax(o_data), np.nanmax(f_data1),np.nanmax(f_data[f_data != -9999]),np.nanmax(dst[name][index1,index2,:,:]))
                        #print(np.nanmin(o_data), np.nanmin(f_data1),np.nanmin(f_data[f_data != -9999]),np.nanmin(dst[name][index1,index2,:,:]))   
                        #print(np.nansum(o_data), np.nansum(f_data1),np.nansum(f_data[f_data != -9999]),np.nansum(dst[name][index1,index2,:,:]))  

                    count = count + variable.shape[1]

            end = process_time()
            print("Generating variable: " +name+ " takes  {}".format(end-start))

        else:

            # keep variables with the same dimension
            xerr = dst.createVariable(name, variable.datatype, variable.dimensions, zlib=True, complevel=5)
            # Copy variable attributes
            dst[name].setncatts(src[name].__dict__)
            # Copy the data

            dst[name][...] = src[name][...]
            
            end = process_time()
            print("Copying variable: " +name+ " takes  {}".format(end-start))
            
        if count > 50:
            dst.close()   # output the variable into a file to save memory

            dst = nc.Dataset(output_file, 'a')

            count = 0
        
        print(count)

    # Close the files
    src.close()
    dst.close()
    
if __name__ == '__main__':
    main()
# Out:
# the domain file is domain.lnd.TES_PT.4km.1d.c240827.nc
# (433, 1321) (433, 1321) (433, 1321) (571993,) 571993
# Checking on varibale: mxsoil_color dimensions: ()
# Copying variable: mxsoil_color takes  0.013557797999993682
# 0
# Checking on varibale: mxsoil_order dimensions: ()
# Copying variable: mxsoil_order takes  0.0006599970000138455
# 0
# Checking on varibale: SOIL_COLOR dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: SOIL_COLOR dimensions: ('lsmlat', 'lsmlon')
# Generating variable: SOIL_COLOR takes  0.23105170300001987
# 1
# Checking on varibale: SOIL_ORDER dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: SOIL_ORDER dimensions: ('lsmlat', 'lsmlon')
# Generating variable: SOIL_ORDER takes  0.24265949100001194
# 2
# Checking on varibale: PCT_SAND dimensions: ('nlevsoi', 'lsmlat', 'lsmlon')
# Working on varibale: PCT_SAND dimensions: ('nlevsoi', 'lsmlat', 'lsmlon')
# Generating variable: PCT_SAND takes  4.0754594219999944
# 12
# Checking on varibale: PCT_CLAY dimensions: ('nlevsoi', 'lsmlat', 'lsmlon')
# Working on varibale: PCT_CLAY dimensions: ('nlevsoi', 'lsmlat', 'lsmlon')
# Generating variable: PCT_CLAY takes  4.10145623599999
# 22
# Checking on varibale: ORGANIC dimensions: ('nlevsoi', 'lsmlat', 'lsmlon')
# Working on varibale: ORGANIC dimensions: ('nlevsoi', 'lsmlat', 'lsmlon')
# Generating variable: ORGANIC takes  4.127315350999993
# 32
# Checking on varibale: FMAX dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: FMAX dimensions: ('lsmlat', 'lsmlon')
# Generating variable: FMAX takes  0.39888356599999497
# 33
# Checking on varibale: natpft dimensions: ('natpft',)
# Copying variable: natpft takes  0.12184440099997573
# 33
# Checking on varibale: LANDFRAC_PFT dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: LANDFRAC_PFT dimensions: ('lsmlat', 'lsmlon')
# Generating variable: LANDFRAC_PFT takes  0.2595671370000048
# 34
# Checking on varibale: PFTDATA_MASK dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: PFTDATA_MASK dimensions: ('lsmlat', 'lsmlon')
# Generating variable: PFTDATA_MASK takes  0.36447278399998595
# 35
# Checking on varibale: PCT_NATVEG dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: PCT_NATVEG dimensions: ('lsmlat', 'lsmlon')
# Generating variable: PCT_NATVEG takes  0.2822115310000015
# 36
# Checking on varibale: PCT_CROP dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: PCT_CROP dimensions: ('lsmlat', 'lsmlon')
# Generating variable: PCT_CROP takes  0.40494035999998346
# 37
# Checking on varibale: PCT_NAT_PFT dimensions: ('natpft', 'lsmlat', 'lsmlon')
# Working on varibale: PCT_NAT_PFT dimensions: ('natpft', 'lsmlat', 'lsmlon')
# Generating variable: PCT_NAT_PFT takes  7.560856446999992
# 0
# Checking on varibale: MONTHLY_LAI dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Working on varibale: MONTHLY_LAI dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Generating variable: MONTHLY_LAI takes  92.45188635500003
# 0
# Checking on varibale: MONTHLY_SAI dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Working on varibale: MONTHLY_SAI dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Generating variable: MONTHLY_SAI takes  92.56570687300001
# 0
# Checking on varibale: MONTHLY_HEIGHT_TOP dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Working on varibale: MONTHLY_HEIGHT_TOP dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Generating variable: MONTHLY_HEIGHT_TOP takes  90.38933346399995
# 0
# Checking on varibale: MONTHLY_HEIGHT_BOT dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Working on varibale: MONTHLY_HEIGHT_BOT dimensions: ('time', 'lsmpft', 'lsmlat', 'lsmlon')
# Generating variable: MONTHLY_HEIGHT_BOT takes  90.417032124
# 0
# Checking on varibale: time dimensions: ('time',)
# Copying variable: time takes  0.0022350509999569113
# 0
# Checking on varibale: AREA dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: AREA dimensions: ('lsmlat', 'lsmlon')
# Generating variable: AREA takes  0.23582859199996165
# 1
# Checking on varibale: LONGXY dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: LONGXY dimensions: ('lsmlat', 'lsmlon')
# Generating variable: LONGXY takes  0.25740650299997014
# 2
# Checking on varibale: LATIXY dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: LATIXY dimensions: ('lsmlat', 'lsmlon')
# Generating variable: LATIXY takes  0.2566275060000862
# 3
# Checking on varibale: EF1_BTR dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: EF1_BTR dimensions: ('lsmlat', 'lsmlon')
# Generating variable: EF1_BTR takes  0.25533896599995387
# 4
# Checking on varibale: EF1_FET dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: EF1_FET dimensions: ('lsmlat', 'lsmlon')
# Generating variable: EF1_FET takes  0.25798328299993045
# 5
# Checking on varibale: EF1_FDT dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: EF1_FDT dimensions: ('lsmlat', 'lsmlon')
# Generating variable: EF1_FDT takes  0.2571247299999868
# 6
# Checking on varibale: EF1_SHR dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: EF1_SHR dimensions: ('lsmlat', 'lsmlon')
# Generating variable: EF1_SHR takes  0.2564178920000586
# 7
# Checking on varibale: EF1_GRS dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: EF1_GRS dimensions: ('lsmlat', 'lsmlon')
# Generating variable: EF1_GRS takes  0.2577371340000809
# 8
# Checking on varibale: EF1_CRP dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: EF1_CRP dimensions: ('lsmlat', 'lsmlon')
# Generating variable: EF1_CRP takes  0.2572830579999845
# 9
# Checking on varibale: CANYON_HWR dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: CANYON_HWR dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: CANYON_HWR takes  0.770067483000048
# 12
# Checking on varibale: EM_IMPROAD dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: EM_IMPROAD dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: EM_IMPROAD takes  0.7930372160000161
# 15
# Checking on varibale: EM_PERROAD dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: EM_PERROAD dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: EM_PERROAD takes  0.7932293320000099
# 18
# Checking on varibale: EM_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: EM_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: EM_ROOF takes  0.7941528759999983
# 21
# Checking on varibale: EM_WALL dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: EM_WALL dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: EM_WALL takes  0.792980478000004
# 24
# Checking on varibale: HT_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: HT_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: HT_ROOF takes  0.7941885709999497
# 27
# Checking on varibale: THICK_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: THICK_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: THICK_ROOF takes  0.7928214689999322
# 30
# Checking on varibale: THICK_WALL dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: THICK_WALL dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: THICK_WALL takes  0.7923994789999824
# 33
# Checking on varibale: T_BUILDING_MAX dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: T_BUILDING_MAX dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: T_BUILDING_MAX takes  0.7925598660000333
# 36
# Checking on varibale: T_BUILDING_MIN dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: T_BUILDING_MIN dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: T_BUILDING_MIN takes  0.7916208849999293
# 39
# Checking on varibale: WIND_HGT_CANYON dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: WIND_HGT_CANYON dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: WIND_HGT_CANYON takes  0.7914131090000183
# 42
# Checking on varibale: WTLUNIT_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: WTLUNIT_ROOF dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: WTLUNIT_ROOF takes  0.7915541849999954
# 45
# Checking on varibale: WTROAD_PERV dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: WTROAD_PERV dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: WTROAD_PERV takes  0.793692061999991
# 48
# Checking on varibale: ALB_IMPROAD_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_IMPROAD_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_IMPROAD_DIR takes  1.553095002999953
# 0
# Checking on varibale: ALB_IMPROAD_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_IMPROAD_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_IMPROAD_DIF takes  1.5018250570000191
# 6
# Checking on varibale: ALB_PERROAD_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_PERROAD_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_PERROAD_DIR takes  1.5781551250000803
# 12
# Checking on varibale: ALB_PERROAD_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_PERROAD_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_PERROAD_DIF takes  1.5796708510000599
# 18
# Checking on varibale: ALB_ROOF_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_ROOF_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_ROOF_DIR takes  1.586357004999968
# 24
# Checking on varibale: ALB_ROOF_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_ROOF_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_ROOF_DIF takes  1.5888402610000867
# 30
# Checking on varibale: ALB_WALL_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_WALL_DIR dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_WALL_DIR takes  1.5881470060000993
# 36
# Checking on varibale: ALB_WALL_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: ALB_WALL_DIF dimensions: ('numrad', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: ALB_WALL_DIF takes  1.5867351110000527
# 42
# Checking on varibale: TK_ROOF dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: TK_ROOF dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: TK_ROOF takes  4.379712659000006
# 0
# Checking on varibale: TK_WALL dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: TK_WALL dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: TK_WALL takes  4.308622936000006
# 15
# Checking on varibale: TK_IMPROAD dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: TK_IMPROAD dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: TK_IMPROAD takes  4.529022241000007
# 30
# Checking on varibale: CV_ROOF dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: CV_ROOF dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: CV_ROOF takes  4.378471936999972
# 45
# Checking on varibale: CV_WALL dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: CV_WALL dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: CV_WALL takes  4.3761319499999445
# 0
# Checking on varibale: CV_IMPROAD dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: CV_IMPROAD dimensions: ('nlevurb', 'numurbl', 'lsmlat', 'lsmlon')
# Generating variable: CV_IMPROAD takes  4.284912967000082
# 15
# Checking on varibale: NLEV_IMPROAD dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: NLEV_IMPROAD dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: NLEV_IMPROAD takes  0.7584884429999192
# 18
# Checking on varibale: peatf dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: peatf dimensions: ('lsmlat', 'lsmlon')
# Generating variable: peatf takes  0.33915814599993155
# 19
# Checking on varibale: abm dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: abm dimensions: ('lsmlat', 'lsmlon')
# Generating variable: abm takes  0.3284144980000292
# 20
# Checking on varibale: gdp dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: gdp dimensions: ('lsmlat', 'lsmlon')
# Generating variable: gdp takes  0.28396032700004525
# 21
# Checking on varibale: SLOPE dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: SLOPE dimensions: ('lsmlat', 'lsmlon')
# Generating variable: SLOPE takes  0.35436070800005837
# 22
# Checking on varibale: STD_ELEV dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: STD_ELEV dimensions: ('lsmlat', 'lsmlon')
# Generating variable: STD_ELEV takes  0.26301133300000856
# 23
# Checking on varibale: binfl dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: binfl dimensions: ('lsmlat', 'lsmlon')
# Generating variable: binfl takes  0.31832612000005156
# 24
# Checking on varibale: Ws dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: Ws dimensions: ('lsmlat', 'lsmlon')
# Generating variable: Ws takes  0.4378335699999525
# 25
# Checking on varibale: Dsmax dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: Dsmax dimensions: ('lsmlat', 'lsmlon')
# Generating variable: Dsmax takes  0.40101626299997406
# 26
# Checking on varibale: Ds dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: Ds dimensions: ('lsmlat', 'lsmlon')
# Generating variable: Ds takes  0.4031574250000176
# 27
# Checking on varibale: LAKEDEPTH dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: LAKEDEPTH dimensions: ('lsmlat', 'lsmlon')
# Generating variable: LAKEDEPTH takes  0.31276889700006905
# 28
# Checking on varibale: F0 dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: F0 dimensions: ('lsmlat', 'lsmlon')
# Generating variable: F0 takes  0.4301113719999421
# 29
# Checking on varibale: P3 dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: P3 dimensions: ('lsmlat', 'lsmlon')
# Generating variable: P3 takes  0.406573572999946
# 30
# Checking on varibale: ZWT0 dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: ZWT0 dimensions: ('lsmlat', 'lsmlon')
# Generating variable: ZWT0 takes  0.40392315999997663
# 31
# Checking on varibale: PCT_WETLAND dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: PCT_WETLAND dimensions: ('lsmlat', 'lsmlon')
# Generating variable: PCT_WETLAND takes  0.4112841800000524
# 32
# Checking on varibale: PCT_LAKE dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: PCT_LAKE dimensions: ('lsmlat', 'lsmlon')
# Generating variable: PCT_LAKE takes  0.26863449699999364
# 33
# Checking on varibale: PCT_GLACIER dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: PCT_GLACIER dimensions: ('lsmlat', 'lsmlon')
# Generating variable: PCT_GLACIER takes  0.2649981839999782
# 34
# Checking on varibale: TOPO dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: TOPO dimensions: ('lsmlat', 'lsmlon')
# Generating variable: TOPO takes  0.2649402879999343
# 35
# Checking on varibale: PCT_URBAN dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Working on varibale: PCT_URBAN dimensions: ('numurbl', 'lsmlat', 'lsmlon')
# Generating variable: PCT_URBAN takes  0.7949659250000423
# 38
# Checking on varibale: URBAN_REGION_ID dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: URBAN_REGION_ID dimensions: ('lsmlat', 'lsmlon')
# Generating variable: URBAN_REGION_ID takes  0.2892923519999613
# 39
# Checking on varibale: APATITE_P dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: APATITE_P dimensions: ('lsmlat', 'lsmlon')
# Generating variable: APATITE_P takes  0.2838996880000195
# 40
# Checking on varibale: LABILE_P dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: LABILE_P dimensions: ('lsmlat', 'lsmlon')
# Generating variable: LABILE_P takes  0.44226465299993833
# 41
# Checking on varibale: OCCLUDED_P dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: OCCLUDED_P dimensions: ('lsmlat', 'lsmlon')
# Generating variable: OCCLUDED_P takes  0.41065599599994584
# 42
# Checking on varibale: SECONDARY_P dimensions: ('lsmlat', 'lsmlon')
# Working on varibale: SECONDARY_P dimensions: ('lsmlat', 'lsmlon')
# Generating variable: SECONDARY_P takes  0.4100977950000697
# 43

# %%
domain_name = 'domain.lnd.TES_SE.4km.2d.c240827.nc' 
r_tessfa = nc.Dataset(domain_name, 'r', format='NETCDF4')
AREA = r_tessfa.variables['area'][...]  # Area is in (lat, lon)


r_tessfa2= nc.Dataset('TES_BOT_domain2.nc', 'r', format='NETCDF4')
TBOT = r_tessfa2.variables['TBOT'][0,:,:]

# %%
x_dim
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x_dim
#
# NameError: name 'x_dim' is not defined

# %%
np.min(AREA)
# Out:
# 5.35673230217526e-08

# %%
    src = nc.Dataset('surfdata.nc', 'r')
    # points = [y,x] coordinates for src's grid
    src_resx = 0.5
    src_resy = 0.5
    src_lat = src.variables['LATIXY'][...]  
    src_lon = src.variables['LONGXY'][...]
    #src_x,src_y = Tlonlat2xy.transform(src_lon,src_lat)
    src_lon[src_lon<0.0]=360+src_lon[src_lon<0.0]

    print( src_lon)
# Out:
# [[2.5000e-01 7.5000e-01 1.2500e+00 ... 3.5875e+02 3.5925e+02 3.5975e+02]
#  [2.5000e-01 7.5000e-01 1.2500e+00 ... 3.5875e+02 3.5925e+02 3.5975e+02]
#  [2.5000e-01 7.5000e-01 1.2500e+00 ... 3.5875e+02 3.5925e+02 3.5975e+02]
#  ...
#  [2.5000e-01 7.5000e-01 1.2500e+00 ... 3.5875e+02 3.5925e+02 3.5975e+02]
#  [2.5000e-01 7.5000e-01 1.2500e+00 ... 3.5875e+02 3.5925e+02 3.5975e+02]
#  [2.5000e-01 7.5000e-01 1.2500e+00 ... 3.5875e+02 3.5925e+02 3.5975e+02]]

# %%
src_lon.size
# Out:
# 259200
